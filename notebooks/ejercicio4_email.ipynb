# %%
import sys
sys.path.append('../src')

# %%
import ejercicio4
import importlib
importlib.reload(ejercicio4)
# Out:
# <module 'ejercicio4' from 'c:\\Users\\Usuario\\Desktop\\Práctica 2\\notebooks\\../src\\ejercicio4.py'>

# %%
email_usuario = input("Ingrese un email: ")

if ejercicio4.validar_email(email_usuario):
    print("El email es válido.")
else:
    print("El email no es válido.")
# Out:
# El email es válido.
