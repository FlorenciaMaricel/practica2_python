# %%
import sys
sys.path.append('../src')

# %%
review = """La película sigue a un grupo de astronautas que 
viajan a Marte
en una misión de rescate. El capitán Torres lidera al equipo 
a través
de tormentas solares y fallos en el sistema de navegación. Al 
llegar
a Marte descubren que la base está abandonada y los 
suministros
destruidos. Torres decide sacrificar la nave nodriza para 
salvar
al equipo y logran volver a la Tierra en una cápsula de 
emergencia.
El final revela que Torres sobrevivió gracias a un pasaje 
secreto."""

# %%
import ejercicio3
import importlib
importlib.reload(ejercicio3)
# Out:
# <module 'ejercicio3' from 'C:\\Users\\Usuario\\Desktop\\Práctica 2\\notebooks\\../src\\ejercicio3.py'>

# %%
entrada = input("Ingresa palabras spoilers separadas por coma: ")
# Out:
# Ingresa palabras spoilers separadas por coma:  jkajwd,dfnjsnd, nnn

# %%
spoilers = [p.strip() for p in entrada.split(",")]
review_censurada = ejercicio3.ocultar_spoilers(review, spoilers)
print(review_censurada)
# Out:
# La película sigue a un grupo de astronautas que viajan a Marte en una misión de rescate. El capitán Torres lidera al equipo a través de tormentas solares y fallos en el sistema de navegación. Al llegar a Marte descubren que la base está abandonada y los suministros destruidos. Torres decide sacrificar la nave nodriza para salvar al equipo y logran volver a la Tierra en una cápsula de emergencia. El final revela que Torres sobrevivió gracias a un pasaje secreto.

# %%
import textwrap
# Aplico textwrap para que la reseña modificada quede legible
review_formateada = textwrap.fill(review_censurada, width=80)
print(review_formateada)
# Out:
# La película sigue a un grupo de astronautas que viajan a Marte en una misión de
# rescate. El capitán Torres lidera al equipo a través de tormentas solares y
# fallos en el sistema de navegación. Al llegar a Marte descubren que la base está
# abandonada y los suministros destruidos. Torres decide sacrificar la nave
# nodriza para salvar al equipo y logran volver a la Tierra en una cápsula de
# emergencia. El final revela que Torres sobrevivió gracias a un pasaje secreto.
