# %%
import sys
sys.path.append('../src')
import importlib
import ejercicio5

importlib.reload(ejercicio5)
# Out:
# <module 'ejercicio5' from 'c:\\Users\\Usuario\\Desktop\\Práctica 2\\notebooks\\../src\\ejercicio5.py'>

# %%
peso = float(input("Ingrese el peso del paquete (kg): ").strip())
zona = input("Ingrese la zona de destino (local/regional/nacional): ").strip()

costo = ejercicio5.calcular_envio(peso, zona)

if costo == "Zona no válida. Las zonas disponibles son: local, regional, nacional.":
    print(costo)
else:
    print(f"Costo de envío: ${costo}")
# Out:
# Costo de envío: $1000
