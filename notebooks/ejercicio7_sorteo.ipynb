# %%
import sys
sys.path.append('../src')

# %%
import importlib
import ejercicio7

importlib.reload(ejercicio7)

# %%
entrada = input("Ingrese los participantes separados por coma: ")

resultado = ejercicio7.sortear_amigo_invisible(entrada)

if isinstance(resultado, str):
    print(resultado)
else:
    participantes, asignaciones = resultado
    print("\nSorteo de amigo invisible:")
    for i in range(len(participantes)):
        print(f"  {participantes[i]} → {asignaciones[i]}")
