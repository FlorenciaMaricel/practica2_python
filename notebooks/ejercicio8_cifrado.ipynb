# %%
import sys
sys.path.append('../src')

# %%
import importlib
import ejercicio8

importlib.reload(ejercicio8)

# %%
mensaje = input("Ingrese un mensaje: ")
desplazamiento = int(input("Ingrese el desplazamiento: "))

mensaje_cifrado = ejercicio8.cifrar_en_cesar(mensaje, desplazamiento)
mensaje_descifrado =ejercicio8.descifrar_en_cesar(mensaje_cifrado, desplazamiento)

print("\nMensaje cifrado:", mensaje_cifrado)
print("Mensaje descifrado:", mensaje_descifrado)
